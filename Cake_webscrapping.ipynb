# %%
import pandas as pd
from bs4 import BeautifulSoup 
import requests
import time

# %%
url = "https://www.allrecipes.com/recipes/276/desserts/cakes/"

# %%
# Fetching html from the website
page = requests.get(url)
# BeautifulSoup enables to find the elements/tags in a webpage 
soup = BeautifulSoup(page.text, "html.parser")

# %%
links = []
for link in soup.find_all('a'):
    links.append(link.get('href'))
print(links[101:120])
# Out:
# ['https://www.allrecipes.com/recipes/338/bread/bread-machine/', 'https://www.allrecipes.com/recipes/342/bread/quick-bread/cornbread/', 'https://www.allrecipes.com/recipes/355/bread/pastries/doughnuts/', 'https://www.allrecipes.com/recipes/350/bread/quick-bread/muffins/', 'https://www.allrecipes.com/recipes/347/bread/quick-bread/pumpkin-bread/', 'https://www.allrecipes.com/recipes/360/bread/quick-bread/', 'https://www.allrecipes.com/recipes/349/bread/yeast-bread/sourdough-bread/', 'https://www.allrecipes.com/recipes/339/bread/yeast-bread/', 'https://www.allrecipes.com/recipes/348/bread/quick-bread/zucchini-bread/', '#', 'https://www.allrecipes.com/recipes/79/desserts/', 'https://www.allrecipes.com/gallery/sugar-free-cookies/', 'https://www.allrecipes.com/gallery/sugar-free-cookies/', 'https://www.allrecipes.com/how-to/baking/', 'https://www.allrecipes.com/recipes/276/desserts/cakes/', 'https://www.allrecipes.com/recipes/860/desserts/cakes/carrot-cake/', 'https://www.allrecipes.com/recipes/387/desserts/cakes/cheesecake/', 'https://www.allrecipes.com/recipes/835/desserts/cakes/chocolate-cake/', 'https://www.allrecipes.com/recipes/362/desserts/cookies/']

# %%
len(links)
# Out:
# 558

# %%
import pandas as pd
recipe_urls = pd.Series([a.get("href") for a in soup.find_all("a")])
recipe_urls = recipe_urls[(recipe_urls.str.contains("dessert-crepes")==False) & 
    (recipe_urls.str.contains("www.allrecipes.com/recipe/")==True)].unique()

# %%
recipe_urls
# Out:
# array(['https://www.allrecipes.com/recipe/17981/one-bowl-chocolate-cake-iii/',
#        'https://www.allrecipes.com/recipe/282825/cannoli-cheesecake/',
#        'https://www.allrecipes.com/recipe/19090/orange-fluff-cake/',
#        'https://www.allrecipes.com/recipe/240463/maple-buttercream-frosting/',
#        'https://www.allrecipes.com/recipe/283067/pistachio-layer-cake-with-cream-cheese-buttercream/',
#        'https://www.allrecipes.com/recipe/25965/blueberry-buttermilk-coffeecake/',
#        'https://www.allrecipes.com/recipe/7400/lite-carrot-cake/',
#        'https://www.allrecipes.com/recipe/281930/dark-chocolate-sheet-cake-with-dark-chocolate-frosting/',
#        'https://www.allrecipes.com/recipe/15750/hummingbird-cake/',
#        'https://www.allrecipes.com/recipe/223199/blood-orange-yogurt-olive-oil-cake/',
#        'https://www.allrecipes.com/recipe/262507/key-lime-coconut-cupcakes/',
#        'https://www.allrecipes.com/recipe/105768/moist-red-velvet-cupcakes/',
#        'https://www.allrecipes.com/recipe/241038/microwave-chocolate-mug-cake/',
#        'https://www.allrecipes.com/recipe/17481/simple-white-cake/',
#        'https://www.allrecipes.com/recipe/7399/tres-leches-milk-cake/',
#        'https://www.allrecipes.com/recipe/7754/a-number-1-banana-cake/',
#        'https://www.allrecipes.com/recipe/7402/carrot-cake-iii/',
#        'https://www.allrecipes.com/recipe/8144/mardi-gras-king-cake/',
#        'https://www.allrecipes.com/recipe/9246/gingerbread-cupcakes-with-cream-cheese-frosting/',
#        'https://www.allrecipes.com/recipe/261755/mini-christmas-cakes/',
#        'https://www.allrecipes.com/recipe/169305/sopapilla-cheesecake-pie/',
#        'https://www.allrecipes.com/recipe/280318/homemade-pound-cake/',
#        'https://www.allrecipes.com/recipe/8088/gooey-butter-cake-iii/',
#        'https://www.allrecipes.com/recipe/49066/the-best-unbaked-cherry-cheesecake-ever/',
#        'https://www.allrecipes.com/recipe/9295/red-velvet-cake/',
#        'https://www.allrecipes.com/recipe/7987/peach-cobbler-dump-cake-i/',
#        'https://www.allrecipes.com/recipe/7515/better-than-sex-cake-ii/',
#        'https://www.allrecipes.com/recipe/7307/mini-cheesecakes-i/',
#        'https://www.allrecipes.com/recipe/15723/vaselopita-greek-new-years-cake/',
#        'https://www.allrecipes.com/recipe/7565/too-much-chocolate-cake/',
#        'https://www.allrecipes.com/recipe/7304/eclair-cake/',
#        'https://www.allrecipes.com/recipe/286259/kims-buttermilk-spice-cake/',
#        'https://www.allrecipes.com/recipe/277220/russian-honey-cake/',
#        'https://www.allrecipes.com/recipe/17393/best-carrot-cake-ever/',
#        'https://www.allrecipes.com/recipe/7986/yellow-cake-made-from-scratch/',
#        'https://www.allrecipes.com/recipe/285858/easy-apple-charlotte/',
#        'https://www.allrecipes.com/recipe/283483/almond-ricotta-cake/',
#        'https://www.allrecipes.com/recipe/236064/our-best-cheesecake/',
#        'https://www.allrecipes.com/recipe/8384/cream-cheese-pound-cake-iii/'],
#       dtype=object)

# %%
len(recipe_urls)
# Out:
# 39

# %%
df = pd.DataFrame(recipe_urls, columns = ['recipe_urls'])

# %%
df['recipe_urls'].astype('str')
# Out:
# 0     https://www.allrecipes.com/recipe/17981/one-bo...
# 1     https://www.allrecipes.com/recipe/282825/canno...
# 2     https://www.allrecipes.com/recipe/19090/orange...
# 3     https://www.allrecipes.com/recipe/240463/maple...
# 4     https://www.allrecipes.com/recipe/283067/pista...
# 5     https://www.allrecipes.com/recipe/25965/bluebe...
# 6     https://www.allrecipes.com/recipe/7400/lite-ca...
# 7     https://www.allrecipes.com/recipe/281930/dark-...
# 8     https://www.allrecipes.com/recipe/15750/hummin...
# 9     https://www.allrecipes.com/recipe/223199/blood...
# 10    https://www.allrecipes.com/recipe/262507/key-l...
# 11    https://www.allrecipes.com/recipe/105768/moist...
# 12    https://www.allrecipes.com/recipe/241038/micro...
# 13    https://www.allrecipes.com/recipe/17481/simple...
# 14    https://www.allrecipes.com/recipe/7399/tres-le...
# 15    https://www.allrecipes.com/recipe/7754/a-numbe...
# 16    https://www.allrecipes.com/recipe/7402/carrot-...
# 17    https://www.allrecipes.com/recipe/8144/mardi-g...
# 18    https://www.allrecipes.com/recipe/9246/gingerb...
# 19    https://www.allrecipes.com/recipe/261755/mini-...
# 20    https://www.allrecipes.com/recipe/169305/sopap...
# 21    https://www.allrecipes.com/recipe/280318/homem...
# 22    https://www.allrecipes.com/recipe/8088/gooey-b...
# 23    https://www.allrecipes.com/recipe/49066/the-be...
# 24    https://www.allrecipes.com/recipe/9295/red-vel...
# 25    https://www.allrecipes.com/recipe/7987/peach-c...
# 26    https://www.allrecipes.com/recipe/7515/better-...
# 27    https://www.allrecipes.com/recipe/7307/mini-ch...
# 28    https://www.allrecipes.com/recipe/15723/vaselo...
# 29    https://www.allrecipes.com/recipe/7565/too-muc...
# 30    https://www.allrecipes.com/recipe/7304/eclair-...
# 31    https://www.allrecipes.com/recipe/286259/kims-...
# 32    https://www.allrecipes.com/recipe/277220/russi...
# 33    https://www.allrecipes.com/recipe/17393/best-c...
# 34    https://www.allrecipes.com/recipe/7986/yellow-...
# 35    https://www.allrecipes.com/recipe/285858/easy-...
# 36    https://www.allrecipes.com/recipe/283483/almon...
# 37    https://www.allrecipes.com/recipe/236064/our-b...
# 38    https://www.allrecipes.com/recipe/8384/cream-c...
# Name: recipe_urls, dtype: object

# %%
df
# Out:
#                                           recipe_urls
# 0   https://www.allrecipes.com/recipe/17981/one-bo...
# 1   https://www.allrecipes.com/recipe/282825/canno...
# 2   https://www.allrecipes.com/recipe/19090/orange...
# 3   https://www.allrecipes.com/recipe/240463/maple...
# 4   https://www.allrecipes.com/recipe/283067/pista...
# 5   https://www.allrecipes.com/recipe/25965/bluebe...
# 6   https://www.allrecipes.com/recipe/7400/lite-ca...
# 7   https://www.allrecipes.com/recipe/281930/dark-...
# 8   https://www.allrecipes.com/recipe/15750/hummin...
# 9   https://www.allrecipes.com/recipe/223199/blood...
# 10  https://www.allrecipes.com/recipe/262507/key-l...
# 11  https://www.allrecipes.com/recipe/105768/moist...
# 12  https://www.allrecipes.com/recipe/241038/micro...
# 13  https://www.allrecipes.com/recipe/17481/simple...
# 14  https://www.allrecipes.com/recipe/7399/tres-le...
# 15  https://www.allrecipes.com/recipe/7754/a-numbe...
# 16  https://www.allrecipes.com/recipe/7402/carrot-...
# 17  https://www.allrecipes.com/recipe/8144/mardi-g...
# 18  https://www.allrecipes.com/recipe/9246/gingerb...
# 19  https://www.allrecipes.com/recipe/261755/mini-...
# 20  https://www.allrecipes.com/recipe/169305/sopap...
# 21  https://www.allrecipes.com/recipe/280318/homem...
# 22  https://www.allrecipes.com/recipe/8088/gooey-b...
# 23  https://www.allrecipes.com/recipe/49066/the-be...
# 24  https://www.allrecipes.com/recipe/9295/red-vel...
# 25  https://www.allrecipes.com/recipe/7987/peach-c...
# 26  https://www.allrecipes.com/recipe/7515/better-...
# 27  https://www.allrecipes.com/recipe/7307/mini-ch...
# 28  https://www.allrecipes.com/recipe/15723/vaselo...
# 29  https://www.allrecipes.com/recipe/7565/too-muc...
# 30  https://www.allrecipes.com/recipe/7304/eclair-...
# 31  https://www.allrecipes.com/recipe/286259/kims-...
# 32  https://www.allrecipes.com/recipe/277220/russi...
# 33  https://www.allrecipes.com/recipe/17393/best-c...
# 34  https://www.allrecipes.com/recipe/7986/yellow-...
# 35  https://www.allrecipes.com/recipe/285858/easy-...
# 36  https://www.allrecipes.com/recipe/283483/almon...
# 37  https://www.allrecipes.com/recipe/236064/our-b...
# 38  https://www.allrecipes.com/recipe/8384/cream-c...

# %%
#to retrive title

url ='https://www.allrecipes.com/recipe/17981/one-bowl-chocolate-cake-iii/'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')
dessert_name = soup.find('h1').text.strip()
print(dessert_name)
# Out:
# One Bowl Chocolate Cake III

# %%
print(soup.select('.recipe-info-section'))
# Out:
# [<div class="recipe-info-section"> <h2 class="hidden-label">Recipe Summary test</h2> <span aria-hidden="true" class="time-stats"><svg aria-hidden="true" height="32px" role="img" viewbox="0 0 24 24" width="32px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g fill="none" fill-rule="evenodd"><path d="m 11.938,19.758 a 7.817,7.817 0 0 1 -7.815,-7.82 7.818,7.818 0 1 1 15.634,0 7.819,7.819 0 0 1 -7.818,7.82 M 11.939,2 c 5.486,0 9.937,4.447 9.937,9.938 0,5.488 -4.45,9.938 -9.937,9.938 C 6.454,21.876 2,17.426 2,11.938 2,6.448 6.454,2 11.939,2 Z m -0.554,5.624 a 0.554,0.554 0 0 0 1.108,0 V 5.64 a 0.554,0.554 0 0 0 -1.108,0 z m 0,10.688 a 0.555,0.555 0 0 0 1.108,0 v -1.984 a 0.551,0.551 0 0 0 -0.551,-0.55 0.553,0.553 0 0 0 -0.557,0.55 z m 7.181,-6.16 c 0.31,0 0.55,-0.247 0.55,-0.55 a 0.547,0.547 0 0 0 -0.55,-0.554 h -1.984 a 0.556,0.556 0 0 0 -0.557,0.555 c 0,0.302 0.251,0.55 0.557,0.55 h 1.984 z m -11.14,0 a 0.552,0.552 0 1 0 0,-1.104 H 5.442 a 0.555,0.555 0 0 0 -0.556,0.555 c 0,0.302 0.25,0.55 0.556,0.55 h 1.982 z m 0.88,-3.5 c 0.082,0.08 0.188,0.12 0.294,0.12 a 0.41,0.41 0 0 0 0.291,-0.12 0.418,0.418 0 0 0 0,-0.588 L 7.899,7.073 a 0.415,0.415 0 0 0 -0.586,0 0.421,0.421 0 0 0 0,0.587 z m 8.13,8.065 c 0.083,0.08 0.19,0.12 0.294,0.12 a 0.413,0.413 0 0 0 0.29,-0.706 l -0.992,-0.993 a 0.418,0.418 0 0 0 -0.585,0 0.42,0.42 0 0 0 0,0.585 z M 15.966,8.652 16.957,7.66 A 0.41471948,0.41471948 0 1 0 16.372,7.072 l -0.989,0.992 a 0.412,0.412 0 0 0 0,0.588 0.412,0.412 0 0 0 0.582,0 z m -8.131,8.066 0.99,-0.994 A 0.41295097,0.41295097 0 1 0 8.242,15.139 L 7.25,16.132 a 0.426,0.426 0 0 0 0,0.586 c 0.08,0.08 0.186,0.12 0.292,0.12 0.106,0 0.215,-0.04 0.293,-0.12 z m 3.628,-2.737 c 0.916,-1.107 4.562,-5.576 2.932,-4.566 -1.859,1.152 -4.516,3.113 -4.516,3.113 a 1.097,1.097 0 0 0 -0.414,0.855 1.085,1.085 0 0 0 1.788,0.83 l 0.004,0.01 c 0,0 0.02,-0.02 0.052,-0.057 0.058,-0.057 0.11,-0.117 0.154,-0.185 z" fill="#e7ab46"></path></g></svg> </span> <section class="recipe-meta-container two-subcol-content clearfix"> <div class="two-subcol-content-wrapper"> <div class="recipe-meta-item"> <div class="recipe-meta-item-header">prep:</div> <div class="recipe-meta-item-body">20 mins </div> </div> <div class="recipe-meta-item"> <div class="recipe-meta-item-header">cook:</div> <div class="recipe-meta-item-body">30 mins </div> </div> <div class="recipe-meta-item"> <div class="recipe-meta-item-header">additional:</div> <div class="recipe-meta-item-body">10 mins </div> </div> <div class="recipe-meta-item"> <div class="recipe-meta-item-header">total:</div> <div class="recipe-meta-item-body">1 hr </div> </div> </div> <div class="two-subcol-content-wrapper"> <div class="recipe-meta-item"><div class="recipe-meta-item-header">Servings:</div> <div class="recipe-meta-item-body">24 </div> </div> <div class="recipe-meta-item"><div class="recipe-meta-item-header">Yield:</div> <div class="recipe-meta-item-body">2 - 9 inch round cake layers </div> </div> </div> </section> <div class="nutrition-info"><a class="nutrition-link" data-label="nutritional value clicked" data-tracking-zone="recipe-interaction" href="#nutrition">Nutrition Info</a></div> </div>]

# %%
ingredients = []
for para in soup.find_all(class_ = 'ingredients-item'):
    ingredients.append(para.get_text().strip())
print(ingredients)
# Out:
# ['2 cups white sugar', '1\u2009¾ cups all-purpose flour', '¾ cup unsweetened cocoa powder', '1\u2009½ teaspoons baking powder', '1\u2009½ teaspoons baking soda', '1 teaspoon salt', '2 eggs', '1 cup milk', '½ cup vegetable oil', '2 teaspoons vanilla extract', '1 cup boiling water']

# %%
#to retrive instructions

instructions = []
for para in soup.select('.instructions-section li'):
    instructions.append(para.get_text().strip())
print(instructions)
# Out:
# ['Step 1   Preheat oven to 350 degrees F (175 degrees C). Grease and flour two nine inch round pans.    Advertisement', 'Step 2   In a large bowl, stir together the sugar, flour, cocoa, baking powder, baking soda and salt. Add the eggs, milk, oil and vanilla, mix for 2 minutes on medium speed of mixer. Stir in the boiling water last. Batter will be thin. Pour evenly into the prepared pans.', 'Step 3   Bake 30 to 35 minutes in the preheated oven, until the cake tests done with a toothpick. Cool in the pans for 10 minutes, then remove to a wire rack to cool completely.']

# %%
#to retrive details

details = []
for para in soup.select('.recipe-info-section'):
    details.append(para.get_text().strip())
print(details)
# Out:
# ['Recipe Summary test      prep: 20 mins    cook: 30 mins    additional: 10 mins    total: 1 hr     Servings: 24   Yield: 2 - 9 inch round cake layers     Nutrition Info']

# %%
#checking image files
urls = pd.Series([a.get("src") for a in soup.find_all("img")])
urls = urls[(urls.str.contains(".jpg")==True) & 
    (urls.str.contains("allrecipes.com")==True) & 
    (urls.str.contains("F60x60")==False) &
    (urls.str.contains("userphotos/")==False) ].unique()
url = urls[0]
print(url)
# Out:
# https://imagesvc.meredithcorp.io/v3/mm/image?url=https%3A%2F%2Fimages.media-allrecipes.com%2Fuserphotos%2F213381.jpg

# %%
#saving image

img_data = requests.get(url).content
with open(str(dessert_name)+".jpg", "wb") as handler:
    handler.write(img_data)

# %% [markdown]
# #CODE

# %%
#dessert names
def dessert(url):
    soup = BeautifulSoup(requests.get(url).content, 'html.parser')
    dessert_name = soup.find('h1').text.strip()
    return dessert_name

# %%
#dessert ingredients
def ingredients(url):
    soup = BeautifulSoup(requests.get(url).content, 'html.parser')
    ingredients = []
    for para in soup.select('.ingredients-section li'):
        ingredients.append(para.get_text().strip())
    return ingredients

# %%
#method
def instructions(url):
    soup = BeautifulSoup(requests.get(url).content, 'html.parser')
    instructions = []
    for para in soup.select('.instructions-section li'):
        instructions.append(para.get_text().strip())
    return instructions

# %%
#description, serves, cooking time, difficulty
def details(url):
    soup = BeautifulSoup(requests.get(url).content, 'html.parser')
    details = []
    for para in soup.select('.recipe-info-section'):
        details.append(para.get_text().strip())
    return details

# %%
#dessert image
def image(url):
    soup = BeautifulSoup(requests.get(url).content, 'html.parser')
    urls = pd.Series([a.get("src") for a in soup.find_all("img")])
    urls = urls[(urls.str.contains(".jpg")==True) & 
        (urls.str.contains("allrecipes.com")==True) & 
        (urls.str.contains("F60x60")==False) &
        (urls.str.contains("userphotos/")==False) ].unique()
    pic = urls[0]
    return pic

# %%
title = []
ing_name = []
method = []
det = []
img = []
for i in range(0,len(df['recipe_urls'])): 
    main_url = df['recipe_urls'][i]
    title.append(dessert(main_url))
    ing_name.append(ingredients(main_url))
    method.append(instructions(main_url))
    det.append(details(main_url))
    img.append(image(main_url))
    img_data = requests.get(img[i]).content
    with open(str(title[i])+".jpg", "wb") as handler:
        handler.write(img_data)

# %%
attribs = ['recipe_name', 'details', 'ingredients','instructions','image_url','recipe_url']
new_df = pd.DataFrame(columns=attribs)
new_df['recipe_name'] = title
new_df['details'] = det
new_df['ingredients'] = ing_name
new_df['instructions'] = method
new_df['image_url'] = img
new_df['recipe_url']= df['recipe_urls']

# %%
new_df
# Out:
#                                           recipe_name  \
# 0                         One Bowl Chocolate Cake III
# 1                                  Cannoli Cheesecake
# 2                                   Orange Fluff Cake
# 3                          Maple Buttercream Frosting
# 4   Pistachio Layer Cake with Cream Cheese Butterc...
# 5                     Blueberry Buttermilk Coffeecake
# 6                                    Lite Carrot Cake
# 7   Dark Chocolate Sheet Cake with Dark Chocolate ...
# 8                                    Hummingbird Cake
# 9                  Blood Orange Yogurt Olive Oil Cake
# 10                          Key Lime-Coconut Cupcakes
# 11                          Moist Red Velvet Cupcakes
# 12                       Microwave Chocolate Mug Cake
# 13                                  Simple White Cake
# 14                            Tres Leches (Milk Cake)
# 15                             A-Number-1 Banana Cake
# 16                                    Carrot Cake III
# 17                               Mardi Gras King Cake
# 18    Gingerbread Cupcakes with Cream Cheese Frosting
# 19                               Mini Christmas Cakes
# 20                           Sopapilla Cheesecake Pie
# 21                                Homemade Pound Cake
# 22                              Gooey Butter Cake III
# 23            The Best Unbaked Cherry Cheesecake Ever
# 24                                    Red Velvet Cake
# 25                          Peach Cobbler Dump Cake I
# 26                            Better Than Sex Cake II
# 27                                 Mini Cheesecakes I
# 28                  Vaselopita - Greek New Years Cake
# 29                            Too Much Chocolate Cake
# 30                                        Eclair Cake
# 31                        Kim's Buttermilk Spice Cake
# 32                                 Russian Honey Cake
# 33                              Best Carrot Cake Ever
# 34                      Yellow Cake Made from Scratch
# 35                               Easy Apple Charlotte
# 36                                Almond Ricotta Cake
# 37                                Our Best Cheesecake
# 38                        Cream Cheese Pound Cake III
#
#                                               details  \
# 0   [Recipe Summary test      prep: 20 mins    coo...
# 1   [Recipe Summary test      prep: 30 mins    coo...
# 2   [Recipe Summary test      prep: 30 mins    coo...
# 3   [Recipe Summary test      prep: 15 mins    tot...
# 4   [Recipe Summary test      prep: 1 hr    cook: ...
# 5   [Recipe Summary test      prep: 30 mins    coo...
# 6   [Recipe Summary test       Servings: 24   Yiel...
# 7   [Recipe Summary test      prep: 30 mins    coo...
# 8   [Recipe Summary test      prep: 20 mins    coo...
# 9   [Recipe Summary test      prep: 20 mins    coo...
# 10  [Recipe Summary test      prep: 10 mins    coo...
# 11  [Recipe Summary test      prep: 30 mins    coo...
# 12  [Recipe Summary test      prep: 5 mins    cook...
# 13  [Recipe Summary test      prep: 20 mins    coo...
# 14  [Recipe Summary test       Servings: 24   Yiel...
# 15  [Recipe Summary test      prep: 30 mins    coo...
# 16  [Recipe Summary test      prep: 30 mins    coo...
# 17  [Recipe Summary test      prep: 1 hr    cook: ...
# 18  [Recipe Summary test       Servings: 12   Yiel...
# 19  [Recipe Summary test      prep: 1 hr    cook: ...
# 20  [Recipe Summary test      prep: 15 mins    coo...
# 21  [Recipe Summary test      prep: 15 mins    coo...
# 22  [Recipe Summary test       Servings: 18   Yiel...
# 23  [Recipe Summary test      prep: 30 mins    add...
# 24  [Recipe Summary test      prep: 25 mins    coo...
# 25  [Recipe Summary test      prep: 10 mins    coo...
# 26  [Recipe Summary test      prep: 30 mins    coo...
# 27  [Recipe Summary test      prep: 30 mins    coo...
# 28  [Recipe Summary test      prep: 30 mins    coo...
# 29  [Recipe Summary test       Servings: 12   Yiel...
# 30  [Recipe Summary test      prep: 25 mins    add...
# 31  [Recipe Summary test      prep: 20 mins    coo...
# 32  [Recipe Summary test      prep: 45 mins    coo...
# 33  [Recipe Summary test      prep: 1 hr 30 mins  ...
# 34  [Recipe Summary test       Servings: 24   Yiel...
# 35  [Recipe Summary test      prep: 15 mins    coo...
# 36  [Recipe Summary test      prep: 20 mins    coo...
# 37  [Recipe Summary test      prep: 15 mins    add...
# 38  [Recipe Summary test      prep: 30 mins    coo...
#
#                                           ingredients  \
# 0   [2 cups white sugar, 1 ¾ cups all-purpose flou...
# 1   [cooking spray, 2 ¼ cups graham cracker crumbs...
# 2   [1 ½ cups sifted cake flour, ½ cup white sugar...
# 3   [4 cups confectioners' sugar, ½ cup butter, so...
# 4   [cooking spray, 3 cups unsalted pistachios, 2 ...
# 5   [4 cups all-purpose flour, 3 teaspoons baking ...
# 6   [1 cup cake flour, 1 cup whole wheat flour, 1 ...
# 7   [1 ¾ cups all-purpose flour, 1 cup dark cocoa ...
# 8   [3 cups all-purpose flour, 2 cups white sugar,...
# 9   [1 ½ cups all-purpose flour, 2 teaspoons bakin...
# 10  [1 ½ cups sifted all-purpose flour, 1 ½ teaspo...
# 11  [½ cup butter, 1 ½ cups white sugar, 2 eggs, 1...
# 12  [¼ cup all-purpose flour, ¼ cup white sugar, 2...
# 13  [1 cup white sugar, ½ cup butter, 2 eggs, 2 te...
# 14  [1 ½ cups all-purpose flour, 1 teaspoon baking...
# 15  [2 ½ cups all-purpose flour, 1 tablespoon baki...
# 16  [4 eggs, 1 ¼ cups vegetable oil, 2 cups white ...
# 17  [1 cup milk, ¼ cup butter, 2 (.25 ounce) packa...
# 18  [5 tablespoons unsalted butter, softened, ½ cu...
# 19  [3 cups dried currants, 1 ¼ cups raisins, 1 cu...
# 20  [2 (8 ounce) packages cream cheese, softened, ...
# 21  [3 ¼ cups white sugar, ¾ pound unsalted butter...
# 22  [1 (18.25 ounce) package yellow cake mix, ½ cu...
# 23  [1 ¼ cups graham cracker crumbs, ¼ cup margari...
# 24  [½ cup shortening, 1 ½ cups white sugar, 2 egg...
# 25  [2 (16 ounce) cans peaches in heavy syrup, 1 (...
# 26  [1 (18.25 ounce) package devil's food cake mix...
# 27  [1 (12 ounce) package vanilla wafers, 2 (8 oun...
# 28  [1 cup butter, 2 cups white sugar, 3 cups all-...
# 29  [1 (18.25 ounce) package devil's food cake mix...
# 30  [2 (3.5 ounce) packages instant vanilla puddin...
# 31  [2 cups all-purpose flour, 2 teaspoons ground ...
# 32  [¾ cup wildflower honey, 3 tablespoons cold wa...
# 33  [6 cups grated carrots, 1 cup brown sugar, 1 c...
# 34  [2 cups all-purpose flour, 1 ½ cups white suga...
# 35  [nonstick cooking spray, 3 cups peeled and dic...
# 36  [½ cup unsalted butter, at room temperature, ¾...
# 37  [1 ¾ cups HONEY MAID Graham Cracker Crumbs, ⅓ ...
# 38  [1 (8 ounce) package cream cheese, 1 ½ cups bu...
#
#                                          instructions  \
# 0   [Step 1   Preheat oven to 350 degrees F (175 d...
# 1   [Step 1   Preheat the oven to 325 degrees F (1...
# 2   [Step 1   Position a rack in the center of the...
# 3   [Step 1   Beat confectioners' sugar, butter, a...
# 4   [Step 1   Preheat the oven to 350 degrees F (1...
# 5   [Step 1   Preheat oven to 350 degrees F (175 d...
# 6   [Step 1   Preheat oven to 350 degrees F (175 d...
# 7   [Step 1   Preheat the oven to 350 degrees F (1...
# 8   [Step 1   Preheat oven to 350 degrees F (175 d...
# 9   [Step 1   Preheat oven to 350 degrees F (175 d...
# 10  [Step 1   Preheat the oven to 350 degrees F (1...
# 11  [Step 1   Preheat oven to 350 degrees F (175 d...
# 12  [Step 1   Mix flour, sugar, cocoa powder, baki...
# 13  [Step 1   Preheat oven to 350 degrees F (175 d...
# 14  [Step 1   Preheat oven to 350 degrees F (175 d...
# 15  [Step 1   Preheat oven to 350 degrees F (175 d...
# 16  [Step 1   Preheat oven to 350 degrees F (175 d...
# 17  [Step 1   Scald milk, remove from heat and sti...
# 18  [Step 1   Preheat the oven to 350 degrees F (1...
# 19  [Step 1   Combine currants, raisins, sultana r...
# 20  [Step 1   Preheat an oven to 350 degrees F (17...
# 21  [Step 1   Preheat the oven to 325 degrees F (1...
# 22  [Step 1   Preheat oven to 350 degrees F (175 d...
# 23  [Step 1   Mix together graham cracker crumbs, ...
# 24  [Step 1   Preheat oven to 350 degrees F (175 d...
# 25  [Step 1   Preheat oven to 375 degrees F (190 d...
# 26  [Step 1   Bake cake according to package direc...
# 27  [Step 1   Preheat oven to 350 degrees F (175 d...
# 28  [Step 1   Preheat oven to 350 degrees F (175 d...
# 29  [Step 1   Preheat oven to 350 degrees F (175 d...
# 30  [Step 1   Stir pudding mix, whipped topping, a...
# 31  [Step 1   Preheat the oven to 350 degrees F (1...
# 32  [Step 1   Pour honey into a deep saucepan over...
# 33  [Step 1   In a medium bowl, combine grated car...
# 34  [Step 1   Preheat oven to 350 degrees F (175 d...
# 35  [Step 1   Preheat the oven to 350 degrees F (1...
# 36  [Step 1   Preheat the oven to 325 degrees F (1...
# 37  [Step 1   Heat oven to 350 degrees F.    Adver...
# 38  [Step 1   Preheat oven to 325 degrees F (160 d...
#
#                                             image_url  \
# 0   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 1   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 2   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 3   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 4   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 5   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 6   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 7   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 8   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 9   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 10  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 11  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 12  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 13  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 14  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 15  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 16  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 17  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 18  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 19  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 20  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 21  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 22  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 23  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 24  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 25  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 26  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 27  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 28  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 29  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 30  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 31  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 32  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 33  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 34  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 35  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 36  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 37  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 38  https://imagesvc.meredithcorp.io/v3/mm/image?u...
#
#                                            recipe_url
# 0   https://www.allrecipes.com/recipe/17981/one-bo...
# 1   https://www.allrecipes.com/recipe/282825/canno...
# 2   https://www.allrecipes.com/recipe/19090/orange...
# 3   https://www.allrecipes.com/recipe/240463/maple...
# 4   https://www.allrecipes.com/recipe/283067/pista...
# 5   https://www.allrecipes.com/recipe/25965/bluebe...
# 6   https://www.allrecipes.com/recipe/7400/lite-ca...
# 7   https://www.allrecipes.com/recipe/281930/dark-...
# 8   https://www.allrecipes.com/recipe/15750/hummin...
# 9   https://www.allrecipes.com/recipe/223199/blood...
# 10  https://www.allrecipes.com/recipe/262507/key-l...
# 11  https://www.allrecipes.com/recipe/105768/moist...
# 12  https://www.allrecipes.com/recipe/241038/micro...
# 13  https://www.allrecipes.com/recipe/17481/simple...
# 14  https://www.allrecipes.com/recipe/7399/tres-le...
# 15  https://www.allrecipes.com/recipe/7754/a-numbe...
# 16  https://www.allrecipes.com/recipe/7402/carrot-...
# 17  https://www.allrecipes.com/recipe/8144/mardi-g...
# 18  https://www.allrecipes.com/recipe/9246/gingerb...
# 19  https://www.allrecipes.com/recipe/261755/mini-...
# 20  https://www.allrecipes.com/recipe/169305/sopap...
# 21  https://www.allrecipes.com/recipe/280318/homem...
# 22  https://www.allrecipes.com/recipe/8088/gooey-b...
# 23  https://www.allrecipes.com/recipe/49066/the-be...
# 24  https://www.allrecipes.com/recipe/9295/red-vel...
# 25  https://www.allrecipes.com/recipe/7987/peach-c...
# 26  https://www.allrecipes.com/recipe/7515/better-...
# 27  https://www.allrecipes.com/recipe/7307/mini-ch...
# 28  https://www.allrecipes.com/recipe/15723/vaselo...
# 29  https://www.allrecipes.com/recipe/7565/too-muc...
# 30  https://www.allrecipes.com/recipe/7304/eclair-...
# 31  https://www.allrecipes.com/recipe/286259/kims-...
# 32  https://www.allrecipes.com/recipe/277220/russi...
# 33  https://www.allrecipes.com/recipe/17393/best-c...
# 34  https://www.allrecipes.com/recipe/7986/yellow-...
# 35  https://www.allrecipes.com/recipe/285858/easy-...
# 36  https://www.allrecipes.com/recipe/283483/almon...
# 37  https://www.allrecipes.com/recipe/236064/our-b...
# 38  https://www.allrecipes.com/recipe/8384/cream-c...

# %%
new_df.to_csv("Cake.csv")

# %%
old_df = pd.read_csv("Cake.csv")

# %%
final_df = old_df.append(new_df,ignore_index=True)

# %%
final_df.to_csv("Cake_final.csv")
